# %% [markdown]
# # Test Notebook
#
# This is a test notebook to demonstrate the review functionality.

# %%
# A simple Python code cell
print("Hello, World! A wild change appears!")
# Out:
# Hello, World!

# %% [markdown]
# ## Data Analysis Example
#
# Let's demonstrate some basic data analysis:

# %%
import pandas as pd
import numpy as np

# Create sample data
data = {
    'A': np.random.randn(100),
    'B': np.random.randn(100)
}
df = pd.DataFrame(data)
